# %%
import importlib
import API_CF
importlib.reload(API_CF)

from API_CF import API_CF

# %%
CF = API_CF()

# %%
problems = CF.get_problems()
problems
# Out:
#        contestId index                    name         type  points  \
# 0           2110     F                 Faculty  PROGRAMMING  3000.0
# 1           2110     E                  Melody  PROGRAMMING  2250.0
# 2           2110     D         Fewer Batteries  PROGRAMMING  2000.0
# 3           2110     C                  Racing  PROGRAMMING  1500.0
# 4           2110     B      Down with Brackets  PROGRAMMING   750.0
# ...          ...   ...                     ...          ...     ...
# 10423          2     B     The least round way  PROGRAMMING     NaN
# 10424          2     A                  Winner  PROGRAMMING     NaN
# 10425          1     C  Ancient Berland Circus  PROGRAMMING     NaN
# 10426          1     B             Spreadsheet  PROGRAMMING     NaN
# 10427          1     A          Theatre Square  PROGRAMMING     NaN
#
#                                                     tags  rating
# 0                     [brute force, math, number theory]     NaN
# ...

# %%
st = CF.get_stats()
st
# Out:
#        contestId index  solvedCount
# 0           2110     F          612
# 1           2110     E          890
# 2           2110     D         3948
# 3           2110     C         8979
# 4           2110     B        16225
# ...          ...   ...          ...
# 10423          2     B        11549
# 10424          2     A        28360
# 10425          1     C         5931
# 10426          1     B        24024
# 10427          1     A       284403
#
# [10428 rows x 3 columns]

# %%
problems = CF.get_problems()

# %%
problems
# Out:
#        contestId index                    name         type  points  \
# 0           2110     F                 Faculty  PROGRAMMING  3000.0
# 1           2110     E                  Melody  PROGRAMMING  2250.0
# 2           2110     D         Fewer Batteries  PROGRAMMING  2000.0
# 3           2110     C                  Racing  PROGRAMMING  1500.0
# 4           2110     B      Down with Brackets  PROGRAMMING   750.0
# ...          ...   ...                     ...          ...     ...
# 10423          2     B     The least round way  PROGRAMMING     NaN
# 10424          2     A                  Winner  PROGRAMMING     NaN
# 10425          1     C  Ancient Berland Circus  PROGRAMMING     NaN
# 10426          1     B             Spreadsheet  PROGRAMMING     NaN
# 10427          1     A          Theatre Square  PROGRAMMING     NaN
#
#                                                     tags  rating  solvedCount
# ...

# %%
sub = CF.get_user_submissions("kuramu")

# %%
sub
# Out:
#     problem_id                      name  contestId index  attempts  solved  \
# 0        1028A               Find Square       1028     A         1   False
# 1      102951A          Maximum Distance     102951     A         2    True
# 2      102961H      Maximum Subarray Sum     102961     H         1    True
# 3      103274C           Cypher Decypher     103274     C         1    True
# 4      103274E               Escape Room     103274     E         7   False
# ..         ...                       ...        ...   ...       ...     ...
# 494        59A                      Word         59     A         1    True
# 495       616B          Dinner with Emma        616     B         1    True
# 496       755C     PolandBall and Forest        755     C         2    True
# 497       802A  Heidi and Library (easy)        802     A         1   False
# 498       802G          Fake News (easy)        802     G         1    True
#
# ...

# %%
CF.get_user_info("quicksouls")
# Out:
# {'handle': 'QuickSouls',
#  'rating': 858,
#  'maxRating': 935,
#  'rank': 'newbie',
#  'maxRank': 'newbie',
#  'contribution': 0,
#  'friendOfCount': 10}

# %%
CF.get_user_rating_history("quicksouls")
# Out:
#    contestId                     contestName      handle   rank  \
# 0       1926   Codeforces Round 928 (Div. 4)  QuickSouls  22975
# 1       1941   Codeforces Round 933 (Div. 3)  QuickSouls  22511
# 2       1950   Codeforces Round 937 (Div. 4)  QuickSouls  19383
# 3       1955   Codeforces Round 938 (Div. 3)  QuickSouls  16607
# 4       1968   Codeforces Round 943 (Div. 3)  QuickSouls  12775
# 5       2050   Codeforces Round 991 (Div. 3)  QuickSouls  12092
# 6       2055   Codeforces Round 996 (Div. 2)  QuickSouls  17018
# 7       2060   Codeforces Round 998 (Div. 3)  QuickSouls  20944
# 8       2065  Codeforces Round 1003 (Div. 4)  QuickSouls  23873
# 9       2093  Codeforces Round 1016 (Div. 3)  QuickSouls  11235
#
#    ratingUpdateTimeSeconds  oldRating  newRating
# 0               1708361400          0        363
# 1               1710175800        363        595
# 2               1711645200        595        765
# 3               1712595000        765        856
# ...

# %%
CF.get_contest_list(True)
# Out:
#           id                                               name  type  \
# 0     100001           2010 Codeforces Beta Round #1 (training)  ICPC
# 1     100003  2008-2009 Всероссийская командная олимпиада шк...  ICPC
# 2     100002  2002-2003 ACM-ICPC Northeastern European Regio...  ICPC
# 3     100005  2010-2011 Цикл интернет-олимпиад. Вторая коман...  ICPC
# 4     100004                                      Local Contest  ICPC
# ...      ...                                                ...   ...
# 2264  105910    The 23rd Sichuan University Programming Contest  ICPC
# 2265  105920                                Soy Cup #1: Firefly  ICPC
# 2266  105922  The 18th Jilin Provincial Collegiate Programmi...  ICPC
# 2267  105925                      SBC Brazilian Phase Zero 2025  ICPC
# 2268  105924  The 2025 CCPC National Invitational Contest (N...  ICPC
#
#          phase  frozen  durationSeconds  \
# 0     FINISHED   False             7200
# 1     FINISHED   False            18000
# ...

# %%
CF.get_rated_list()
# Out:
#                lastName     country  lastOnlineTimeSeconds        city  \
# 0           Korotkevich     Belarus             1748123757       Gomel
# 1                 Jiang       China             1747673889   Chongqing
# 2                  Zhou       China             1748038266    Hangzhou
# 3               Radecki      Poland             1748069779      Warsaw
# 4              Romashov      Russia             1748130311     Barnaul
# ...                 ...         ...                    ...         ...
# 43770               NaN       Egypt             1748109945  Al Khānkah
# 43771          Tadokoro       Japan             1747042854       Tokyo
# 43772               NaN  Azerbaijan             1747406253         NaN
# 43773              No 1       China             1748095270      Burang
# 43774  (hidden alt acc)       Egypt             1746458340         NaN
#
#        rating  friendOfCount  \
# 0        3843          80695
# 1        3700          38140
# ...
